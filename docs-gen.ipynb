# %%
from collections import deque
from docx import Document
from docx.oxml.text.paragraph import CT_P
from docx.oxml.table import CT_Tbl
from docx.oxml import OxmlElement
from urllib.parse import urlparse

# %%
# 顺序读取 word 文档内容，保存为节点列表
def read_ordered_elements(file_path):
    doc = Document(file_path)
    elements = []
    
    # 按原生顺序遍历文档元素
    for child in doc.element.body.iterchildren():
        if isinstance(child, CT_P):
            # 段落处理
            para = child.xpath('.//w:t')
            text = ''.join([t.text for t in para if t.text])
            elements.append(("Paragraph", text))
        elif isinstance(child, CT_Tbl):
            # 表格处理
            table = []
            for row in child.xpath('.//w:tr'):
                row_data = []
                for cell in row.xpath('.//w:tc'):
                    cell_text = ''.join([t.text for t in cell.xpath('.//w:t')])
                    row_data.append(cell_text)
                table.append(row_data)
            elements.append(("Table", table))
    
    return elements

# 删除段落方法
def delete_paragraph(paragraph):
    p_element = paragraph._element  # 获取XML元素
    p_parent = p_element.getparent()  # 获取父节点
    p_parent.remove(p_element)  # 从父节点中移除
    p_element._p = p_element._element = None  # 释放内存
    
results = read_ordered_elements("C:/Users/wayne/Desktop/ns-api-docs.docx")

# %%
# 读取接口文档，根据接口URL 保存为 接口URL --> 文档内容 的字典
api_docs = {}
curr_api = None
fq = deque(maxlen=5)
for idx, (elem_type, content) in enumerate(results):
    txt = ''
    if elem_type == 'Paragraph':
        txt = {'type':'para', 'content': content.strip()}
        if txt['content'].startswith('接口URL'):
            curr_api = txt['content']
            api_docs[curr_api] = []
            api_docs[curr_api].extend(fq)
        fq.append(txt)
    elif elem_type == 'Table':
        txt = []
        for row in content:
            txt.append(row)
        txt = {'type':'table', 'content': txt}
    if curr_api:
        api_docs[curr_api].append(txt)

# 增加 path --> 文档, path+query --> 文档映射
docs_by_path = {}
docs_by_path_query = {}
for k, v in api_docs.items():
    parsed = urlparse('//' + k.split("：")[1])
    path_and_query = parsed.path + ("?" + parsed.query if parsed.query else "")
    docs_by_path[parsed.path] = v
    docs_by_path_query[path_and_query] = v

# %%
# 计算 url 参数，body 参数，output 输出所在的索引
def mio(gen_api):
    # if len(gen_api) == 26:
    #     m, i, o = 8, 12, 15
    # elif len(gen_api) == 29:
    #     m, i, o = 8, 15, 18
    # else:
    #     m, i, o = 8, 15, 18
    m, u, i, o = 8, None, None, None
    for idx, line in enumerate(gen_api):
        if u is None and line['type'] == 'para' and line['content'].startswith('URI参数说明'):
            u = idx + 1
        if i is None and line['type'] == 'para' and line['content'].startswith('请求体参数说明'):
            i = idx + 1
        if i and o is None and line['type'] == 'para' and line['content'].startswith('返回参数说明'):
            o = idx + 1
    return (m, u, i, o)


dd = Document("C:/Users/wayne/Desktop/详细设计.docx")

editing = False

deleting = False
confirm_delete = False

curr_api = None
gen_api = None

api_method_para = None

for i, para in enumerate(dd.paragraphs):    
    if para.text.strip() == '投入品管理系统':
        editing = True
    if editing is False:
        continue
    if hasattr(para, 'style') and hasattr(para.style, 'name'):
        if para.style.name == 'Heading 4':
            deleting = False
            continue
        if para.style.name == 'Heading 6':
            deleting = True
            confirm_delete = False
            continue
    if deleting:
        if para.text.strip().startswith('请求方式') or para.text.strip().startswith('接口状态'):
            api_method_para = para
        if para.text.strip().startswith('请求地址') or para.text.strip().startswith('接口URL'):
            curr_api = para.text.strip()
            parsed = urlparse('//' + curr_api.split('：')[1])
            pq = parsed.path + ("?" + parsed.query if parsed.query else "")
            gen_api = docs_by_path_query.get(pq)
            if gen_api is None:
                gen_api = docs_by_path.get(parsed.path)
            continue
        if para.text.strip().startswith('请求参数') or para.text.strip().startswith('云端MockUrl'):
            if gen_api is None:
                print(curr_api)
            else:
                # print(curr_api, len(gen_api))
                m, u, i, o = mio(gen_api)
                # 该请求方式
                api_method_para.text = gen_api[m]['content']
                p_in, p_out = gen_api[i]['content'], gen_api[o]['content']
                q_in = []
                if u:
                    q_in = gen_api[u]['content']
                # 拼接出入参数描述
                doc_text = '输入项：\n给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。\n'
                
                for idx in range(1, len(q_in)):
                    i = q_in[idx]
                    if len(i) == 5:
                        doc_text += f'{i[0]}: {i[2]}, {i[1]} {i[4] if i[4] != "暂无描述" else ""}\n'
                    elif len(i) == 1:
                        doc_text += '无 url 请求参数\n'
                    else:
                        print(i)
                for idx in range(1, len(p_in)):
                    i = p_in[idx]
                    if len(i) == 5:
                        doc_text += f'{i[0]}: {i[2]}, {i[1]} {i[4] if i[4] != "暂无描述" else ""}\n'
                    elif len(i) == 1:
                        doc_text += '无 body 请求参数\n'
                    else:
                        print(i)
                doc_text += '输出项：\n给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。\n'
                for idx in range(1, len(p_out)):
                    i = p_out[idx]
                    if len(i) == 4:
                        doc_text += f'{i[0]}: {i[2]}, {i[1]} {i[3] if i[3] != "暂无描述" else ""}\n'
                    elif len(i) == 1:
                        doc_text += '无请求参数\n'
                    else:
                        print(i)
                # print(doc_text)
                # print()
                para.text = doc_text
            confirm_delete = True
            continue
        if confirm_delete:
            # delete_paragraph(para)
            pass
                   

dd.save("详细设计-v3.docx")
# Out:
# 请求地址：localhost:8080/supplier/operate
# 请求地址：localhost:8080/supplier/operate
# 请求地址：localhost:8080/input/stock/detail/get
# 请求地址：localhost:8080/plant/task/stats/get

# %%
x = docs_by_path.get('/input/prohibit/list')
print(len(x))
# 26
# print(x[8])
# print(x[12])
# print(x[15])

# 29 
# print(x[8])
# print(x[15])
# print(x[18])

#31
# print(x[8])
# print(x[15])
# print(x[18])
print(mio(x))
print()
x
# Out:
# 29
# (8, 12, 15, 18)
# [{'type': 'para', 'content': '返回参数说明：(201)失败'},
#  {'type': 'para', 'content': ''},
#  {'type': 'para', 'content': '列表 [input:prohibit:list]'},
#  {'type': 'para', 'content': ''},
#  {'type': 'para', 'content': '接口状态：已完成'},
#  {'type': 'para',
#   'content': '接口URL：localhost:8080/input/prohibit/list?searchValue=&pageNum=1&pageSize=1'},
#  {'type': 'para', 'content': '云端MockUrl：/input/prohibit/list'},
#  {'type': 'para', 'content': 'Content-Type：application/json'},
#  {'type': 'para', 'content': '请求方式：get'},
#  {'type': 'para', 'content': '接口备注：暂无描述'},
#  {'type': 'para', 'content': ''},
#  {'type': 'para', 'content': 'URI参数说明：'},
#  {'type': 'table',
#   'content': [['参数名', '示例值', '参数类型', '是否必填', '参数描述'],
#    ['searchValue', '', 'String', '否', '暂无描述'],
#    ['pageNum', '1', 'Text', '是', '暂无描述'],
#    ['pageSize', '1', 'Text', '是', '暂无描述']]},
#  {'type': 'para', 'content': ''},
#  {'type': 'para', 'content': '请求体参数说明：'},
#  {'type': 'table',
#   'content': [['参数名', '示例值', '参数类型', '是否必填', '参数描述'], ['无请求参数 KEY/VALUE 类型']]},
#  {'type': 'para', 'content': ''},
#  {'type': 'para', 'content': '返回参数说明：(200)成功'},
#  {'type': 'table',
#   'content': [['参数名', '示例值', '参数类型', '参数描述'],
#    ['code', '200', 'Integer', '暂无描述'],
#    ['rows', '', 'Array', '暂无描述'],
#    ['rows.amount', '1.23', 'Number', '暂无描述'],
#    ['rows.bankCardCode', '银行卡号', 'String', '暂无描述'],
#    ['rows.bankName', '银行名称', 'String', '暂无描述'],
#    ['rows.corpId', '1', 'Integer', '暂无描述'],
#    ['rows.id', '6', 'Integer', '暂无描述'],
#    ['rows.isSys', 'false', 'Boolean', '暂无描述'],
#    ['rows.name', '名称', 'String', '暂无描述'],
#    ['rows.remark', '备注', 'String', '暂无描述'],
#    ['rows.shops', '', 'Array', '暂无描述'],
#    ['rows.shops.id', '1', 'Integer', '暂无描述'],
#    ['total', '6', 'Integer', '暂无描述']]},
#  {'type': 'para', 'content': ''},
#  {'type': 'para', 'content': '返回示例：(200)成功'},
#  {'type': 'table',
#   'content': [['{"code": 200,"rows": [{"amount": 1.23,"bankCardCode": "银行卡号","bankName": "银行名称","corpId": 1,"id": 6,"isSys": false,"name": "名称","remark": "备注","shops": [{"id": 1}]},{"amount": 1.23,"bankCardCode": "银行卡号","bankName": "银行名称","corpId": 1,"id": 5,"isSys": false,"name": "名称","remark": "备注","shops": [{"id": 2}]},{"amount": 1.23,"bankCardCode": "银行卡号","bankName": "银行名称","corpId": 1,"id": 4,"isSys": false,"name": "名称","remark": "备注","shops": [{"id": 1}]},{"amount": 1.23,"bankCardCode": "银行卡号","bankName": "银行名称","corpId": 1,"id": 3,"isSys": false,"name": "名称","remark": "备注","shops": [{"id": 1}]},{"amount": 1.23,"bankCardCode": "银行卡号","bankName": "银行名称","corpId": 1,"id": 2,"isSys": false,"name": "名称","remark": "备注","shops": [{"id": 1}]},{"amount": 1.23,"bankCardCode": "银行卡号","bankName": "银行名称","corpId": 1,"id": 1,"isSys": false,"name": "名称","remark": "备注","shops": [{"id": 1}]}],"total": 6}']]},
#  {'type': 'para', 'content': ''},
#  {'type': 'para', 'content': '返回参数说明：(201)失败'},
#  {'type': 'table',
#   'content': [['参数名', '示例值', '参数类型', '参数描述'], ['无请求参数 KEY/VALUE 类型']]},
#  {'type': 'para', 'content': ''},
#  {'type': 'para', 'content': '导出 [input:prohibit:export]'},
#  {'type': 'para', 'content': ''},
#  {'type': 'para', 'content': '接口状态：已完成'}]

# %%
def gen_doc_txt(gen_api):
    m, u, i, o = mio(gen_api)
    # 该请求方式
    api_method_para.text = gen_api[m]['content']
    p_in, p_out = gen_api[i]['content'], gen_api[o]['content']
    q_in = []
    if u:
        q_in = gen_api[u]['content']
    # 拼接出入参数描述
    doc_text = '输入项：\n给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。\n'
    
    for idx in range(1, len(q_in)):
        i = q_in[idx]
        if len(i) == 5:
            doc_text += f'{i[0]}: {i[2]}, {i[1]} {i[4] if i[4] != "暂无描述" else ""}\n'
        elif len(i) == 1:
            doc_text += '无 url 请求参数\n'
        else:
            print(i)
    for idx in range(1, len(p_in)):
        i = p_in[idx]
        if len(i) == 5:
            doc_text += f'{i[0]}: {i[2]}, {i[1]} {i[4] if i[4] != "暂无描述" else ""}\n'
        elif len(i) == 1:
            doc_text += '无 body 请求参数\n'
        else:
            print(i)
    doc_text += '输出项：\n给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。\n'
    for idx in range(1, len(p_out)):
        i = p_out[idx]
        if len(i) == 4:
            doc_text += f'{i[0]}: {i[2]}, {i[1]} {i[3] if i[3] != "暂无描述" else ""}\n'
        elif len(i) == 1:
            doc_text += '无请求参数\n'
        else:
            print(i)
    return doc_text

for k, v in docs_by_path_query.items():
    txt = gen_doc_txt(v)
    print(k)
    print(txt)
    print()
# Out:
# /login
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Number, 200
# token: String, eyJhbGciOiJIUzUxMiJ9.eyJqdGkiOiJmNDhhMmU0Zi04Yjk3LTQ0OGMtYTk3OC0wNzA0NDhlZjRhM2QifQ.B5VodjSIgYOLlTLesoBUcloIt_wcfo6S9ES-zOrBe9WKZZom6-WSJSCj7kivHy87mFBNdUN6aJM7Ae5xl_Q0fA 认证令牌
#
#
# /wechat/common/weChatLogin
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Number, 200
# token: String, eyJhbGciOiJIUzUxMiJ9.eyJqdGkiOiJmNDhhMmU0Zi04Yjk3LTQ0OGMtYTk3OC0wNzA0NDhlZjRhM2QifQ.B5VodjSIgYOLlTLesoBUcloIt_wcfo6S9ES-zOrBe9WKZZom6-WSJSCj7kivHy87mFBNdUN6aJM7Ae5xl_Q0fA 认证令牌
#
#
# /monitor/job/run
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /wechat/common/getUsersByRole?deptId=0&userId=0&roleKey=farm_administrator&tenantId=1
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 0
# userId: String, 0
# roleKey: String, farm_administrator
# tenantId: String, 1
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /dashboard/plant/plan/stats?deptId=100
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Object,
# data.itemA: Integer, 2 进行中
#
#
# /dashboard/sales/order/stats?deptId=100
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Object,
# data.itemB: Integer, 1 已完成数
# data.itemA: Integer, 6 订单总数
# data.itemD: Integer, 4 当前逾期
# data.itemC: Integer, 17 完成进度
#
#
# /dashboard/plant/task/stats?deptId=100
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Object,
# data.itemB: Integer, 31 待派
# data.itemA: Integer, 46 准备进行或在进行的任务
# data.itemC: Integer, 28 逾期未完成
#
#
# /dashboard/farmland/inspect/stats?deptId=100
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Object,
# data.itemA: Integer, 16 准备进行或在进行的任务
# data.itemB: Integer, 36 待派
# data.itemC: Integer, 13 逾期未完成
#
#
# /dashboard/delivery/order/stats?deptId=100
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Object,
# data.itemB: Integer, 4 昨日发货
# data.itemA: Integer, 1 今日发货
# data.item7: Array,
# data.item7.createBy: Null, null
# data.item7.createTime: Null, null
# data.item7.updateBy: Null, null
# data.item7.updateTime: Null, null
# data.item7.remark: Null, null
# data.item7.id: Null, null
# data.item7.tenantId: Null, null
# data.item7.deptId: Null, null
# data.item7.orderNo: Null, null
# data.item7.orderDate: String, 2025-01-03 日期
# data.item7.customerId: Null, null
# data.item7.senderName: Null, null
# data.item7.senderPhone: Null, null
# data.item7.senderAddress: Null, null
# data.item7.receiverName: Null, null
# data.item7.receiverPhone: Null, null
# data.item7.receiverAddress: Null, null
# data.item7.attachments: Null, null
# data.item7.userId: Null, null
# data.item7.orderStatus: Null, null
# data.item7.status: Null, null
# data.item7.depts: Null, null
# data.item7.customerName: Null, null
# data.item7.userName: Null, null
# data.item7.fromStatus: Null, null
# data.item7.toStatus: Null, null
# data.item7.statuses: Null, null
# data.item7.details: Null, null
# data.item7.items: Null, null
# data.item7.refOrderId: Null, null
# data.item7.startDate: Null, null
# data.item7.endDate: Null, null
# data.item7.quantity: Integer, 0 发货量
# data.itemC: Integer, -75 较昨日%
#
#
# /dashboard/plant/type/stats?deptId=100&startDate=2024-10-24&endDate=2024-12-24
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# startDate: String, 2024-10-24
# endDate: String, 2024-12-24
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Array,
# data.typeId: String, c5fbd6434b6a4b82b63df0b4fc74ec10
# data.typeName: String, 耕地
# data.taskArea: Integer, 0 任务
# data.finishArea: Integer, 0 当前完成
# data.completionRate: Integer, 0 %
#
#
# /dashboard/input/product/stats?deptId=100
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Object,
# data.itemB: Integer, 0 化肥
# data.itemA: Integer, 6 种子
# data.itemD: Integer, 7 种子+化肥+农药
# data.itemC: Integer, 1 农药
#
#
# /dashboard/input/product/stats/v2?deptId=100
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Object,
# data.itemB: Integer, 33 玉米
# data.itemA: Integer, 0 水稻
# data.itemD: Integer, 0 大豆
# data.itemC: Integer, 0 小麦
# data.itemE: Integer, 33 合计
#
#
# /dashboard/input/in/stock/stats?deptId=100
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Object,
# data.itemB: Integer, 1 种子
# data.itemA: Integer, 1 入库笔数
# data.itemD: Integer, 0 农药
# data.itemC: Integer, 0 化肥
#
#
# /dashboard/input/out/stock/stats?deptId=100
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Object,
# data.itemB: Integer, 0 种子
# data.itemA: Integer, 0 出库笔数
# data.itemD: Integer, 0 农药
# data.itemC: Integer, 0 化肥
#
#
# /big/screen/data?scene=农事大屏&module=关键指标&deptId=100&year=2024
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# scene: String, 农事大屏
# module: String, 关键指标
# deptId: String, 100 部门
# year: String, 2024
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /big/screen/data?scene=农事大屏&module=投入品&deptId=100&year=2024&type=radar
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# scene: String, 农事大屏
# module: String, 投入品
# deptId: String, 100
# year: String, 2024
# type: String, radar 雷达图
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /big/screen/plant/task/stats?deptId=100&year=2024
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Object,
# data.itemA: Integer, 0 待派
# data.itemB: Integer, 31 未读
# data.itemC: Integer, 14 逾期未完成
# data.itemD: Integer, 12 进行中
#
#
# /big/screen/plant/task/list/v2?deptId=&year=&type=C&pageNum=1&pageSize=10
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String,
# year: String,
# type: String, C A 待派 B 未读 C 逾期未完成 D 进行中
# pageNum: String, 1
# pageSize: String, 10
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Object,
# data.itemA: Integer, 0 待派
# data.itemB: Integer, 31 未读
# data.itemC: Integer, 14 逾期未完成
# data.itemD: Integer, 12 进行中
#
#
# /big/screen/farmland/inspect/stats?deptId=100&year=2024
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Object,
# data.itemA: Integer, 0 待派
# data.itemB: Integer, 0 未读
# data.itemC: Integer, 0 逾期未完成
# data.itemD: Integer, 0 进行中
#
#
# /big/screen/farmland/inspect/list/v2?deptId=100&year=2024&type=B&pageNum=1&pageSize=10
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# type: String, B A 待派 B 未读 C 逾期未完成 D 进行中
# pageNum: String, 1
# pageSize: String, 10
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# total: Integer, 0
# pageNum: Integer, 1
# rows: Array,  A-待派 返回巡田计划列表 数据同巡田计划；其他 返回巡田任务列表 数据同巡田任务
# code: Integer, 200
# msg: String, 查询成功
#
#
# /big/screen/plant/plan/stats?deptId=100&year=2024
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Object,
# data.itemB: Integer, 1 已完成
# data.itemA: Integer, 15 未开始
# data.itemD: Integer, 6 完成%
# data.itemC: Integer, 1 进行中
#
#
# /big/screen/plant/plan/list?deptId=100&year=2024&planStatus=B&pageNum=1&pageSize=10
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# planStatus: String, B A 未开始 B 进行中 C 已完成
# pageNum: String, 1
# pageSize: String, 10
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# total: Integer, 31
# pageNum: Integer, 1
# rows: Array,
# rows.createBy: Null, null
# rows.createTime: String, 2024-12-14 19:12:06 创建时间
# rows.updateBy: Null, null
# rows.updateTime: Null, null
# rows.remark: String,  备注
# rows.id: String, 0e9ae262c10f41c385c8b2fa471059a6 id
# rows.tenantId: String, 1
# rows.deptId: Integer, 100
# rows.name: String, 计划1 名称
# rows.cropId: String, 2
# rows.seedId: String, 3
# rows.seedName: String, 种子3
# rows.quantity: Integer, 22
# rows.unit: String, 吨
# rows.plantYear: Integer, 2024
# rows.startDate: String, 2024-12-14 计开始时间
# rows.endDate: String, 2024-12-18 结束时间
# rows.startEndDateStr: Null, null
# rows.farmlands: Array,
# rows.farmlands.createBy: Null, null
# rows.farmlands.createTime: Null, null
# rows.farmlands.updateBy: Null, null
# rows.farmlands.updateTime: Null, null
# rows.farmlands.remark: Null, null 备注
# rows.farmlands.id: String, 13 id
# rows.farmlands.deptId: Null, null
# rows.farmlands.deptName: Null, null
# rows.farmlands.code: String, 12
# rows.farmlands.areaId: Null, null
# rows.farmlands.areaName: Null, null
# rows.farmlands.areaCascadeId: Null, null
# rows.farmlands.address: Null, null 地址
# rows.farmlands.area: Null, null
# rows.farmlands.warrantArea: Null, null
# rows.farmlands.polygon: Null, null
# rows.farmlands.attribute: Null, null
# rows.farmlands.adminId: Null, null
# rows.farmlands.adminName: Null, null
# rows.farmlands.crops: Null, null
# rows.farmlands.status: Null, null
# rows.farmlands.source: Null, null
# rows.farmlands.sourceId: Null, null
# rows.farmlands.tenantId: Null, null
# rows.attachments: Array,  附件
# rows.planStatus: String, A
# rows.status: String, A
# rows.i: Null, null
# rows.depts: Null, null
# rows.cropName: String, 玉米
# rows.targetName: String, 22.000吨
# rows.farmlandId: Null, null 农田id
# rows.farmlandArea: Number, 81.43 农田总面积
# rows.farmlandAdmins: Null, null
# rows.fromStatus: Null, null
# rows.toStatus: Null, null
# rows.statuses: Null, null
# rows.details: Null, null
# rows.orderId: Null, null
# rows.orderNo: Null, null
# rows.order: Null, null
# rows.orders: Null, null
# rows.totalOfOrders: Null, null
# rows.status2: Null, null
# code: Integer, 200
# msg: String, 查询成功
#
#
# /big/screen/plant/crop/list?deptId=100&year=2024
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /big/screen/plant/farmland/list?deptId=100&year=2024&cropId=1&attribute=1
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# cropId: String, 1 作物
# attribute: String, 1 1 自有 2 托管
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /big/screen/plant/farmland/list/v1?deptId=100&year=2024&farmlandId=13
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# farmlandId: String, 13
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# total: Integer, 1
# pageNum: Integer, 1
# rows: Array,
# rows.createBy: Null, null
# rows.createTime: Null, null
# rows.updateBy: Null, null
# rows.updateTime: Null, null
# rows.remark: Null, null
# rows.id: Null, null
# rows.tenantId: Null, null
# rows.deptId: Null, null
# rows.name: Null, null
# rows.cropPlanId: Null, null
# rows.cropId: Null, null
# rows.seedId: Null, null
# rows.seedName: Null, null
# rows.quantity: Null, null
# rows.unit: Null, null
# rows.plantYear: Null, null
# rows.startDate: String, 2024-12-15 起止日期
# rows.endDate: String, 2024-12-18 起止日期
# rows.startEndDateStr: Null, null
# rows.farmlands: Null, null
# rows.attachments: Null, null
# rows.planStatus: Null, null
# rows.status: Null, null
# rows.i: Null, null
# rows.depts: Null, null
# rows.cropName: String, 水稻 作物
# rows.targetName: String, nullnull
# rows.farmlandId: Null, null
# rows.farmlandArea: Null, null
# rows.farmlandAdmins: Null, null
# rows.fromStatus: Null, null
# rows.toStatus: Null, null
# rows.statuses: Null, null
# rows.detail: Null, null
# rows.details: Null, null
# rows.orderId: Null, null
# rows.orderNo: Null, null
# rows.order: Null, null
# rows.orders: Null, null
# rows.totalOfOrders: Null, null
# rows.status2: Null, null
# rows.node: Null, null
# rows.actQuantity: Null, null
# rows.remoteSenseData: Null, null
# code: Integer, 200
# msg: String, 查询成功
#
#
# /big/screen/farmland/inspect/list?deptId=100&year=2024&farmlandId=1
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# farmlandId: String, 1
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# total: Integer, 1
# pageNum: Integer, 1
# rows: Array,
# rows.createBy: String, 32
# rows.createTime: String, 2024-12-03 12:14:48
# rows.updateBy: Null, null
# rows.updateTime: String, 2024-12-03 12:16:10
# rows.remark: Null, null
# rows.id: String, c35cd6681e77433d9e400be13b63cb9d
# rows.tenantId: Null, null
# rows.deptId: Integer, 100
# rows.userId: Integer, 32
# rows.userName: Null, null
# rows.userPhone: Null, null
# rows.type: Integer, 1
# rows.planId: String, 09c85e023e224593847e4fe1f9c29b94
# rows.planName: String, 玉米XXX巡田计划 计划名称
# rows.scopeId: String, 2e346cfd56584f6ba9eb61006ceeccfb
# rows.scopeName: Null, null
# rows.farmlands: Null, null
# rows.startDate: String, 2024-12-03 巡田日期
# rows.endDate: String, 2024-12-03 巡田日期
# rows.startEndDateStr: Null, null
# rows.content: String,
# rows.attachments: Null, null
# rows.read: Boolean, true
# rows.readTime: String, 2024-12-03 12:16:07
# rows.address: String, 浙江省嘉兴市南湖区南湖街道广场路59号西南约105米
# rows.location: Object,
# rows.location.lon: Number, 120.7555
# rows.location.lat: Number, 30.74501
# rows.status: String, C
# rows.i: Null, null
# rows.fromStatus: Null, null
# rows.toStatus: Null, null
# rows.statuses: Null, null
# rows.depts: Null, null
# rows.farmlandId: Null, null
# rows.finishStartDate: Null, null
# rows.finishEndDate: Null, null
# rows.year: Null, null
# rows.overdue: Null, null
# rows.details: Null, null
# rows.flows: Null, null
# rows.typeName: String, 临时任务
# code: Integer, 200
# msg: String, 查询成功
#
#
# /big/screen/plant/farmland/list/v2?deptId=100&year=2024&farmlandId=101
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# farmlandId: String, 101
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# total: Integer, 1
# pageNum: Integer, 1
# rows: Array,
# rows.createBy: Null, null
# rows.createTime: Null, null
# rows.updateBy: Null, null
# rows.updateTime: Null, null
# rows.remark: Null, null
# rows.id: Null, null
# rows.tenantId: Null, null
# rows.taskId: Null, null
# rows.typeId: Null, null
# rows.modeId: Null, null
# rows.taskTypeId: Null, null
# rows.endDate: String, 2024-12-12 实施日期
# rows.cropId: Null, null
# rows.productId: Null, null
# rows.content: Null, null
# rows.planQuantity: Null, null
# rows.quantity: Null, null
# rows.unit: Null, null
# rows.result: Null, null
# rows.startTime: Null, null
# rows.endTime: Null, null
# rows.status: Null, null
# rows.i: Null, null
# rows.planId: Null, null
# rows.typeName: Null, null
# rows.modeName: String, 无人机 实施方式
# rows.cropName: Null, null
# rows.productName: String, 化肥 投入品名称
# rows.fromStatus: Null, null
# rows.toStatus: Null, null
# rows.farmlandId: Null, null
# rows.depts: Null, null
# rows.plantYear: Null, null
# code: Integer, 200
# msg: String, 查询成功
#
#
# /big/screen/machinery/task/list?deptId=100&year=2024&farmlandId=6
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# farmlandId: String, 6
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# total: Integer, 1
# pageNum: Integer, 1
# rows: Array,
# rows.createBy: Null, null
# rows.createTime: Null, null
# rows.updateBy: Null, null
# rows.updateTime: Null, null
# rows.remark: Null, null
# rows.id: Null, null
# rows.deptId: Null, null
# rows.farmlandId: Null, null
# rows.type: Null, null
# rows.cropType: Null, null
# rows.taskType: Null, null
# rows.beginTime: Null, null
# rows.endTime: Null, null
# rows.operatorAdminId: Null, null
# rows.operatorId: Null, null
# rows.readStatus: Null, null
# rows.source: Null, null
# rows.status: Null, null
# rows.assignmentType: Null, null
# rows.percentComplete: Null, null
# rows.operatorAdminReadStatus: Null, null
# rows.operatorReadStatus: Null, null
# rows.machineryId: Null, null
# rows.isManual: Null, null
# rows.operatorAdminName: Null, null
# rows.machNum: Integer, 0
# rows.jobArea: Integer, 0 作业面积
# rows.jobTime: Integer, 0 作业时间
# rows.task: Null, null
# rows.taskTypeName: String, 拖拉机作业 作业类型
# rows.tableName: Null, null
# code: Integer, 200
# msg: String, 查询成功
#
#
# /big/screen/abnormal/list?deptId=100&year=2024&farmlandId=1
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# farmlandId: String, 1
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# total: Integer, 1
# pageNum: Integer, 1
# rows: Array,
# rows.createBy: Null, null
# rows.createTime: String, 2024-12-13 16:16:41 上报时间
# rows.updateBy: Null, null
# rows.updateTime: Null, null
# rows.remark: Null, null
# rows.id: Null, null
# rows.createUserId: Null, null
# rows.deptId: Null, null
# rows.location: Null, null
# rows.locationType: Null, null
# rows.farmlandId: Null, null
# rows.locationLng: Null, null
# rows.locationLat: Null, null
# rows.polygon: Null, null
# rows.grade: Null, null
# rows.gradeName: Null, null
# rows.description: Null, null
# rows.tel: Null, null
# rows.handleUserId: Null, null
# rows.handleUserTel: Null, null
# rows.handleUserName: Null, null
# rows.handleTime: Null, null
# rows.handleDept: Null, null
# rows.handleDesc: Null, null
# rows.status: Null, null
# rows.statusName: Null, null
# rows.statusToInt: Null, null
# rows.soure: Null, null
# rows.abnormalInfoFileList: Null, null
# rows.abnormalInfo: Null, null
# rows.abnormalProgressVoList: Null, null
# rows.readBy: Null, null
# rows.readTime: Null, null
# rows.readTel: Null, null
# rows.isRead: Null, null
# rows.isWeb: Null, null
# rows.isWx: Null, null
# rows.userIds: Null, null
# rows.abnormalType: Null, null
# rows.abnormalTypeName: String, 病虫害/苗情 异常类型
# rows.tjsb: Null, null
# code: Integer, 200
# msg: String, 查询成功
#
#
# /big/screen/data?scene=投入品大屏&module=关键指标&deptId=100&year=2024
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# scene: String, 投入品大屏
# module: String, 关键指标
# deptId: String, 100 部门
# year: String, 2024
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /big/screen/input/type/list?tenantId=14&deptId=&year=
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# tenantId: String, 14
# deptId: String,
# year: String,
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /big/screen/plant/mode/list?tenantId=1&deptId=&year=
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# tenantId: String, 1
# deptId: String,
# year: String,
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /big/screen/plant/task/detail/list?tenantId=1&deptId=100&year=2024&farmlandId=4
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# tenantId: String, 1
# deptId: String, 100
# year: String, 2024
# farmlandId: String, 4 农田id
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# total: Integer, 2
# pageNum: Integer, 1
# rows: Array,
# rows.productId: String, b0c9e4042a98401eaefe59895b342e67 投入品id
# rows.productName: String, 名称8 投入品名称
# rows.unit: String, 单位 单位
# rows.planQuantity: Integer, 21 计划总投入
# rows.quantity: Integer, 20 已投入
# rows.waitQuantity: Integer, 0 即将投入
# rows.planWaitQuantity: Integer, 1 计划待投入
# code: Integer, 200
# msg: String, 查询成功
#
#
# /big/screen/plant/task/detail/stats/v1?tenantId=1&deptId=100&year=2024
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# tenantId: String, 1
# deptId: String, 100
# year: String, 2024
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# total: Integer, 2
# pageNum: Integer, 1
# rows: Array,
# rows.productId: String, b0c9e4042a98401eaefe59895b342e67 投入品id
# rows.productName: String, 名称8 投入品名称
# rows.unit: String, 单位 单位
# rows.quantity: Number, 0.75 亩均投入量
# code: Integer, 200
# msg: String, 查询成功
#
#
# /big/screen/plant/task/detail/stats/v2?tenantId=1&deptId=100&year=2024
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# tenantId: String, 1
# deptId: String, 100
# year: String, 2024
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# total: Integer, 2
# pageNum: Integer, 1
# rows: Array,
# rows.productId: String, b0c9e4042a98401eaefe59895b342e67 投入品id
# rows.productName: String, 名称8 投入品名称
# rows.unit: String, 单位 单位
# rows.quantity: Number, 89.49 总投入量
# code: Integer, 200
# msg: String, 查询成功
#
#
# /big/screen/plant/task/detail/stats/v3?tenantId=1&deptId=100&year=2024
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# tenantId: String, 1
# deptId: String, 100
# year: String, 2024
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# total: Integer, 2
# pageNum: Integer, 1
# rows: Array,
# rows.modeId: String, ac87054d873e41ad970f6d329dcd03a4
# rows.modeName: String, 机器 实施方式
# rows.area: Number, 175.04 面积 亩
# code: Integer, 200
# msg: String, 查询成功
#
#
# /big/screen/plant/farmland/list/v3?tenantId=1&deptId=100&year=2024&modeId=a49b3f102a814c46a6f900b1bbdf40b5&productId=
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# tenantId: String, 1
# deptId: String, 100
# year: String, 2024
# modeId: String, a49b3f102a814c46a6f900b1bbdf40b5 实施方式 多选使用,分隔
# productId: String,  投入品 多选使用,分隔
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# id: String,  田块id
#
#
# /big/screen/remote/sense/type/list?deptId=100&year=2024
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /big/screen/plant/farmland/list?deptId=100&year=2024&cropId=1
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# cropId: String, 1 作物
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /big/screen/remote/sense/data/list?deptId=100&year=2023&typeId=
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2023
# typeId: String,  检测项
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /big/screen/remote/sense/data/list?deptId=100&year=2024&dataTime=2024-12-12&farmlandId=b71af814c2ad4078abb7d282c2da7776&planId=&productId=&modeId=&pageNum=1&pageSize=10
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# dataTime: String, 2024-12-12
# farmlandId: String, b71af814c2ad4078abb7d282c2da7776 田块
# planId: String,  种植方案
# productId: String,  投入品（种植方案）
# modeId: String,  投入方式（种植方案）
# pageNum: String, 1
# pageSize: String, 10
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /big/screen/remote/sense/type/stats?deptId=100&year=2024&typeId=10146
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# typeId: String, 10146 检测项
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /big/screen/plant/farmland/stats?deptId=&year=&farmlandId=1
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String,
# year: String,
# farmlandId: String, 1
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /big/screen/plant/farmland/get?deptId=&year=&farmlandId=1
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String,
# year: String,
# farmlandId: String, 1 农田id
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /big/screen/plant/plan/get?deptId=100&year=2024&farmlandId=1
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# farmlandId: String, 1 农田id
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Object,
# data.createBy: Null, null
# data.createTime: String, 2024-12-06 16:01:34 创建时间
# data.updateBy: Null, null
# data.updateTime: Null, null
# data.remark: String, 备注 备注
# data.id: String, 1f453d2fd5054c5c8bd4604dae72edf2 id
# data.tenantId: String, 1
# data.deptId: Integer, 100
# data.name: String, 名8 名称
# data.cropPlanId: Null, null
# data.cropId: String, 1 作物
# data.seedId: Null, null
# data.seedName: Null, null
# data.quantity: Number, 12.345
# data.unit: String, 单位（生产目标）
# data.plantYear: Integer, 2024
# data.startDate: String, 2024-01-01 计开始时间
# data.endDate: String, 2025-01-01 结束时间
# data.startEndDateStr: Null, null
# data.farmlands: Array,
# data.farmlands.createBy: Null, null
# data.farmlands.createTime: Null, null
# data.farmlands.updateBy: Null, null
# data.farmlands.updateTime: Null, null
# data.farmlands.remark: Null, null 备注
# data.farmlands.id: String, 1 id
# data.farmlands.deptId: Null, null
# data.farmlands.deptName: Null, null
# data.farmlands.code: Null, null
# data.farmlands.areaId: Null, null
# data.farmlands.areaName: Null, null 行政区域
# data.farmlands.areaCascadeId: Null, null
# data.farmlands.address: Null, null 地址
# data.farmlands.area: Null, null 田块面积
# data.farmlands.warrantArea: Null, null 权证面积
# data.farmlands.polygon: Null, null 农田
# data.farmlands.attribute: Null, null 1
# data.farmlands.adminId: Null, null
# data.farmlands.adminName: Null, null
# data.farmlands.crops: Null, null
# data.farmlands.status: Null, null
# data.farmlands.source: Null, null
# data.farmlands.sourceId: Null, null
# data.farmlands.tenantId: Null, null
# data.attachments: Array,  附件
# data.attachments.id: String, id id
# data.attachments.url: String, url
# data.attachments.fileName: String, fileName
# data.planStatus: String, A A 未开始
# data.status: String, A
# data.i: Null, null
# data.depts: Null, null
# data.cropName: Null, null
# data.targetName: String, 12.345单位（生产目标）
# data.farmlandId: Null, null 农田id
# data.farmlandArea: Null, null 农田总面积
# data.farmlandAdmins: Null, null
# data.fromStatus: Null, null
# data.toStatus: Null, null
# data.statuses: Null, null
# data.detail: Object,
# data.detail.createBy: Null, null
# data.detail.createTime: Null, null
# data.detail.updateBy: Null, null
# data.detail.updateTime: Null, null
# data.detail.remark: String, 备注 备注
# data.detail.id: String, 1e57969ab05449c5a46def1514d5b1c3 id
# data.detail.tenantId: Null, null
# data.detail.planId: String, 1f453d2fd5054c5c8bd4604dae72edf2 计划id
# data.detail.typeId: String, e82289b17416499a8e9d2ec90064a44b
# data.detail.modeId: String, ac87054d873e41ad970f6d329dcd03a4
# data.detail.contents: Array,
# data.detail.contents.content: String, 内容
# data.detail.contents.quantity: Number, 12.345
# data.detail.contents.unit: String, 单位
# data.detail.products: Array,
# data.detail.products.createBy: Null, null
# data.detail.products.createTime: Null, null
# data.detail.products.updateBy: Null, null
# data.detail.products.updateTime: Null, null
# data.detail.products.remark: Null, null 备注
# data.detail.products.id: String, 141274af9b594de1b35fac497b47b686 id
# data.detail.products.tenantId: Null, null
# data.detail.products.typeId: Null, null
# data.detail.products.name: Null, null 名称
# data.detail.products.properties: Null, null
# data.detail.products.alias: Null, null
# data.detail.products.productNo: Null, null
# data.detail.products.unit: Null, null
# data.detail.products.unitRatio: Null, null
# data.detail.products.pictures: Null, null
# data.detail.products.quantity: Number, 12.345
# data.detail.products.status: Null, null
# data.detail.products.i: Null, null
# data.detail.products.typeName: Null, null
# data.detail.products.types: Null, null
# data.detail.products.picture: Null, null
# data.detail.products.fromStatus: Null, null
# data.detail.products.toStatus: Null, null
# data.detail.products.batches: Null, null
# data.detail.machinery: Object,
# data.detail.machinery.createBy: Null, null
# data.detail.machinery.createTime: Null, null
# data.detail.machinery.updateBy: Null, null
# data.detail.machinery.updateTime: Null, null
# data.detail.machinery.remark: Null, null 备注
# data.detail.machinery.id: Null, null id
# data.detail.machinery.deptId: Null, null
# data.detail.machinery.farmlandId: Null, null 农田id
# data.detail.machinery.type: Null, null 雷达图
# data.detail.machinery.cropType: Null, null
# data.detail.machinery.taskType: String, 1-1
# data.detail.machinery.beginTime: Null, null
# data.detail.machinery.endTime: Null, null
# data.detail.machinery.operatorAdminId: String, 11
# data.detail.machinery.operatorId: String,
# data.detail.machinery.readStatus: Null, null
# data.detail.machinery.source: Null, null
# data.detail.machinery.status: Null, null
# data.detail.machinery.assignmentType: Null, null
# data.detail.machinery.percentComplete: String,
# data.detail.machinery.operatorAdminReadStatus: Null, null
# data.detail.machinery.operatorReadStatus: Null, null
# data.detail.machinery.machineryId: Null, null
# data.detail.machinery.isManual: Null, null
# data.detail.machinery.operatorAdminName: Null, null
# data.detail.content: String, 实施规程
# data.detail.cycle: Object,
# data.detail.cycle.type: String, days 雷达图
# data.detail.cycle.num: Integer, 3
# data.detail.cycle.dates: Array, 2024-11-14
# data.detail.cycle.hour: Integer, 15
# data.detail.cycle.minutes: Integer, 30
# data.detail.startDate: String, 2024-01-01 计开始时间
# data.detail.endDate: String, 2025-01-01 结束时间
# data.detail.attachments: Array,  附件
# data.detail.attachments.id: String, id id
# data.detail.attachments.url: String, url
# data.detail.attachments.fileName: String, fileName
# data.detail.nextTime: String, 2024-12-08 15:30:00
# data.detail.nextTimes: Array, 2024-12-08T15:30:00.000+08:00
# data.detail.status: String, A
# data.detail.fromStatus: Null, null
# data.detail.toStatus: Null, null
# data.detail.planStatus: Null, null A 未开始
# data.detail.year: Null, null
# data.detail.depts: Null, null
# data.detail.plans: Null, null
# data.detail.farmlandAdmins: Null, null
# data.detail.completionRate: Null, null
# data.detail.typeName: Null, null
# data.detail.plantType: Null, null
# data.detail.modeName: Null, null
# data.detail.plantMode: Null, null
# data.detail.taskNum: Null, null
# data.detail.recordNum: Null, null
# data.detail.productId: Null, null
# data.detail.farmlandId: Null, null 农田id
# data.detail.noIds: Null, null
# data.detail.types: Null, null
# data.details: Null, null
# data.orderId: Null, null
# data.orderNo: Null, null
# data.order: Null, null
# data.orders: Null, null
# data.totalOfOrders: Null, null
# data.status2: Null, null
# data.node: Null, null
# data.actQuantity: Null, null
# data.remoteSenseData: Null, null
#
#
# /big/screen/plant/task/list?deptId=100&year=2024&farmlandId=1
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String, 100
# year: String, 2024
# farmlandId: String, 1 农田id
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /big/screen/data/list?scene=农事大屏&module=关键指标&deptId=100&year=2024&pageNum=1&pageSize=10
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# scene: String, 农事大屏
# module: String, 关键指标
# deptId: String, 100
# year: String, 2024
# pageNum: String, 1
# pageSize: String, 10
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /big/screen/data/get?id=1
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# id: String, 1
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /big/screen/data/save
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# key: String, sys.index.sideTheme
# name: String, 主框架页-侧边栏主题
# remark: String, 深色主题theme-dark，浅色主题theme-light
# system: String, true
# value: String, theme-dark
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# data: Object,
# data.amount: Number, 1.23
# data.bankCardCode: String, 银行卡号
# data.bankName: String, 银行名称
# data.corpId: Integer, 1
# data.id: Integer, 7
# data.isSys: Boolean, false
# data.name: String, 名称
# data.remark: String, 备注
# data.shops: Array,
# data.shops.id: Integer, 1
#
#
# /big/screen/data/update
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# id: Number, 3
# key: String, sys.index.sideTheme
# name: String, 主框架页-侧边栏主题
# remark: String, 深色主题theme-dark，浅色主题theme-light
# system: String, true
# value: String, theme-dark
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /big/screen/data/delete
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# id: Number, 0
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# data: Object,
# data.corpId: Integer, 1
# data.id: Integer, 1
#
#
# /big/screen/data/list?scene=投入品大屏&module=关键指标&deptId=100&year=2024&pageNum=1&pageSize=10
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# scene: String, 投入品大屏
# module: String, 关键指标
# deptId: String, 100
# year: String, 2024
# pageNum: String, 1
# pageSize: String, 10
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /big/screen/data/list?scene=农事大屏&module=投入品&deptId=100&year=2024&pageNum=1&pageSize=10
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# scene: String, 农事大屏
# module: String, 投入品
# deptId: String, 100
# year: String, 2024
# pageNum: String, 1
# pageSize: String, 10
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /big/screen/data/get?id=5
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# id: String, 5
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /plant/mode/list?name=
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# name: String,
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /plant/mode/get?id=a49b3f102a814c46a6f900b1bbdf40b5
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# id: String, a49b3f102a814c46a6f900b1bbdf40b5
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /plant/mode/save
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# key: String, sys.index.sideTheme
# name: String, 主框架页-侧边栏主题
# remark: String, 深色主题theme-dark，浅色主题theme-light
# system: String, true
# value: String, theme-dark
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# data: Object,
# data.amount: Number, 1.23
# data.bankCardCode: String, 银行卡号
# data.bankName: String, 银行名称
# data.corpId: Integer, 1
# data.id: Integer, 7
# data.isSys: Boolean, false
# data.name: String, 名称
# data.remark: String, 备注
# data.shops: Array,
# data.shops.id: Integer, 1
#
#
# /plant/mode/update
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# id: Number, 3
# key: String, sys.index.sideTheme
# name: String, 主框架页-侧边栏主题
# remark: String, 深色主题theme-dark，浅色主题theme-light
# system: String, true
# value: String, theme-dark
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /plant/mode/delete
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# id: Number, 0
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# data: Object,
# data.corpId: Integer, 1
# data.id: Integer, 1
#
#
# /plant/type/list?isInputTask=true&pageNum=1&pageSize=1
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# isInputTask: String, true 只查 投入品 相关农事类型
# pageNum: String, 1
# pageSize: String, 1
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /plant/type/get?id=3f74411595024fbf8d4fed2ebb3bdadd
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# id: String, 3f74411595024fbf8d4fed2ebb3bdadd
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /plant/type/save
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# key: String, sys.index.sideTheme
# name: String, 主框架页-侧边栏主题
# remark: String, 深色主题theme-dark，浅色主题theme-light
# system: String, true
# value: String, theme-dark
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# data: Object,
# data.amount: Number, 1.23
# data.bankCardCode: String, 银行卡号
# data.bankName: String, 银行名称
# data.corpId: Integer, 1
# data.id: Integer, 7
# data.isSys: Boolean, false
# data.name: String, 名称
# data.remark: String, 备注
# data.shops: Array,
# data.shops.id: Integer, 1
#
#
# /plant/type/update
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# id: Number, 3
# key: String, sys.index.sideTheme
# name: String, 主框架页-侧边栏主题
# remark: String, 深色主题theme-dark，浅色主题theme-light
# system: String, true
# value: String, theme-dark
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /plant/type/delete
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# id: Number, 0
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# data: Object,
# data.corpId: Integer, 1
# data.id: Integer, 1
#
#
# /plant/task/type/list?type=1&name=&status=
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# type: String, 1 1 作业派单 任务类型。 2 生产派单 任务类型
# name: String,
# status: String,  A-启用 B-停用
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /plant/task/type/get?id=17ad0a29339d4faf87c15df3a8905a7e
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# id: String, 17ad0a29339d4faf87c15df3a8905a7e
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /plant/task/type/save
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# key: String, sys.index.sideTheme
# name: String, 主框架页-侧边栏主题
# remark: String, 深色主题theme-dark，浅色主题theme-light
# system: String, true
# value: String, theme-dark
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# data: Object,
# data.amount: Number, 1.23
# data.bankCardCode: String, 银行卡号
# data.bankName: String, 银行名称
# data.corpId: Integer, 1
# data.id: Integer, 7
# data.isSys: Boolean, false
# data.name: String, 名称
# data.remark: String, 备注
# data.shops: Array,
# data.shops.id: Integer, 1
#
#
# /plant/task/type/update
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# id: Number, 3
# key: String, sys.index.sideTheme
# name: String, 主框架页-侧边栏主题
# remark: String, 深色主题theme-dark，浅色主题theme-light
# system: String, true
# value: String, theme-dark
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /plant/task/type/delete
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# id: Number, 0
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# data: Object,
# data.corpId: Integer, 1
# data.id: Integer, 1
#
#
# /plant/machinery/task/type/list
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /plant/crop/list
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /plant/farmland/list?startDate=2024-10-19&endDate=2024-11-23&pageNum=1&pageSize=10
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# startDate: String, 2024-10-19 开始日期
# endDate: String, 2024-11-23 结束日期
# pageNum: String, 1
# pageSize: String, 10
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /plant/crop/plan/list?cropId=1&status=A&searchValue=稻&pageNum=1&pageSize=1
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# cropId: String, 1 作物
# status: String, A A 启用 B 停用
# ...
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /wechat/waybill/order/get?id=02020f0e403541eba1bff021561cc817
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# id: String, 02020f0e403541eba1bff021561cc817
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Object,
# data.createBy: Null, null
# data.createTime: String, 2024-12-02 17:15:54 创建时间
# data.updateBy: Null, null
# data.updateTime: Null, null
# data.remark: String, 描述 备注
# data.id: String, 1536979a6915435caf5153a0617cccdf id
# data.tenantId: Null, null
# data.deptId: Integer, 100 部门
# data.userId: Integer, 14 田间管理员id
# data.customerId: String, 1
# data.attachments: Array,  附件
# data.attachments.id: String, id id
# data.attachments.url: String, url
# data.attachments.fileName: String, fileName
# data.orderDate: String, 2024-11-22
# data.address: String, 登记地点 地址
# data.location: Object,  打卡坐标：经纬度
# data.location.lon: Null, null
# data.location.lat: Number, 29.84706
# data.refOrderId: Null, null
# data.refOrderNo: Null, null
# data.status: String, A
# data.ids: Null, null
# data.depts: Null, null
# data.fromStatus: Null, null
# data.toStatus: Null, null
# data.details: Array,
# data.details.createBy: Null, null
# data.details.createTime: Null, null
# data.details.updateBy: Null, null
# data.details.updateTime: Null, null
# data.details.remark: String, 备注 备注
# data.details.id: String, 8a1172f7db4144cd8820dc8e2f5279e9 id
# data.details.tenantId: Null, null
# data.details.orderId: String, 1536979a6915435caf5153a0617cccdf
# data.details.licensePlate: String, 车牌
# data.details.productName: String, 货品名称
# data.details.unit: String, 货品单位
# data.details.quantity: Number, 1.234
# data.details.attachments: Null, null 附件
# data.plates: Array, 车牌
# data.products: Array, 货品名称
# data.startDate: Null, null 计开始时间
# data.endDate: Null, null 结束时间
#
#
# /wechat/waybill/order/save
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# key: String, sys.index.sideTheme
# name: String, 主框架页-侧边栏主题
# remark: String, 深色主题theme-dark，浅色主题theme-light
# system: String, true
# value: String, theme-dark
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# data: Object,
# data.amount: Number, 1.23
# data.bankCardCode: String, 银行卡号
# data.bankName: String, 银行名称
# data.corpId: Integer, 1
# data.id: Integer, 7
# data.isSys: Boolean, false
# data.name: String, 名称
# data.remark: String, 备注
# data.shops: Array,
# data.shops.id: Integer, 1
#
#
# /wechat/waybill/order/update
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# id: Number, 3
# key: String, sys.index.sideTheme
# name: String, 主框架页-侧边栏主题
# remark: String, 深色主题theme-dark，浅色主题theme-light
# system: String, true
# value: String, theme-dark
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /wechat/waybill/order/delete
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# id: Number, 0
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# data: Object,
# data.corpId: Integer, 1
# data.id: Integer, 1
#
#
# /wechat/license/plate/recognize
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# file: String, ["\/Users\/Jiakun\/Downloads\/WechatIMG193.jpg"]
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# /wechat/system/contacts/list?deptId=&searchValue=
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String,
# searchValue: String,
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# total: Integer, 3
# pageNum: Integer, 1
# rows: Array,
# rows.createBy: Null, null
# rows.createTime: Null, null 创建时间
# rows.updateBy: Null, null
# rows.updateTime: Null, null
# rows.remark: Null, null
# rows.id: String, 2615fbaa462f4d67948f8b5b3532f8cf
# rows.tenantId: Null, null
# rows.parentId: String, 0
# rows.name: String, 名称2
# rows.sortOrder: Integer, 1 排序
# rows.types: Array,
# rows.types.createBy: Null, null
# rows.types.createTime: Null, null
# rows.types.updateBy: Null, null
# rows.types.updateTime: Null, null
# rows.types.remark: Null, null 备注
# rows.types.id: String, 34a55977473e4c39ad874da1c38a6a73 id
# rows.types.tenantId: Null, null
# rows.types.parentId: String, 2615fbaa462f4d67948f8b5b3532f8cf
# rows.types.name: String, 名称 名称
# rows.types.sortOrder: Integer, 1 排序
# rows.types.types: Array,
# code: Integer, 200
# msg: String, 查询成功
#
#
# /wechat/plant/farmland/dept/list?deptId=&searchValue=
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# deptId: String,  有值时，或者 searchValue 无值时，返回 list 第一个 就是 本部门
# searchValue: String,  有值时，不存在 本部门。deptId 有值时，searchValue 无效
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# total: Integer, 3
# pageNum: Integer, 1
# rows: Array,
# rows.createBy: Null, null
# rows.createTime: Null, null 创建时间
# rows.updateBy: Null, null
# rows.updateTime: Null, null
# rows.remark: Null, null
# rows.id: String, 2615fbaa462f4d67948f8b5b3532f8cf
# rows.tenantId: Null, null
# rows.parentId: String, 0
# rows.name: String, 名称2
# rows.sortOrder: Integer, 1 排序
# rows.types: Array,
# rows.types.createBy: Null, null
# rows.types.createTime: Null, null
# rows.types.updateBy: Null, null
# rows.types.updateTime: Null, null
# rows.types.remark: Null, null 备注
# rows.types.id: String, 34a55977473e4c39ad874da1c38a6a73 id
# rows.types.tenantId: Null, null
# rows.types.parentId: String, 2615fbaa462f4d67948f8b5b3532f8cf
# rows.types.name: String, 名称 名称
# rows.types.sortOrder: Integer, 1 排序
# rows.types.types: Array,
# code: Integer, 200
# msg: String, 查询成功
#
#
# /wechat/plant/farmland/list?searchValue=&deptId=100&pageNum=1&pageSize=10
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# searchValue: String,
# deptId: String, 100
# pageNum: String, 1
# pageSize: String, 10
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# total: Integer, 10
# pageNum: Integer, 1
# rows: Array,
# rows.createBy: Null, null
# rows.createTime: String, 2024-11-28 13:51:50 创建时间
# rows.updateBy: String, 1
# rows.updateTime: String, 2024-12-06 15:38:35
# rows.remark: Null, null
# rows.id: String, 1fd9237cde224c7eb0deaf295b3f7a56
# rows.deptId: Integer, 100
# rows.deptName: String, 农场1
# rows.code: String, 1
# rows.areaId: String, 330110
# rows.areaName: String, 浙江省杭州市余杭区
# rows.address: Null, null 地址
# rows.area: String, 173.83
# rows.warrantArea: Null, null
# rows.polygon: String, [{"lat":30.325201834024625,"lon":120.0610688583296},{"lat":30.32517797793217,"lon":120.0610946877816},{"lat":30.32516839343412,"lon":120.06110389818478},{"lat":30.325155500796487,"lon":120.06110890318185},{"lat":30.3251455008782,"lon":120.0611097033044},{"lat":30.325137213811963,"lon":120.06111741198387},{"lat":30.325129428823463,"lon":120.06112622204382},{"lat":30.32512204425279,"lon":120.06113523237808},{"lat":30.325114259075544,"lon":120.06114394230926},{"lat":30.325106972137355,"lon":120.06115165106227},{"lat":30.325098287561076,"lon":120.06116076139715},{"lat":30.325089293442392,"lon":120.06116466537563},{"lat":30.325083109572063,"lon":120.06117397616173},{"lat":30.325077625612455,"lon":120.06118318688208},{"lat":30.325070840192208,"lon":120.0611916966368},{"lat":30.32506456140876,"lon":120.06120381080568},{"lat":30.325058380991273,"lon":120.06121502388339},{"lat":30.325053594924533,"lon":120.0612230331895},{"lat":30.32505021141977,"lon":120.0612323441902},{"lat":30.325044726892312,"lon":120.06124125452256},{"lat":30.325040239947207,"lon":120.06124876323834},{"lat":30.325035154375517,"lon":120.06125707287065},{"lat":30.325028493911827,"lon":120.06127929921105},{"lat":30.32502924974764,"lon":120.06130993632938},{"lat":30.325027369331377,"lon":120.06132084935783},{"lat":30.3250260929974,"lon":120.06133396509273},{"lat":30.325022812013778,"lon":120.06134467774832},{"lat":30.325019832886248,"lon":120.06135639163267},{"lat":30.325015651405323,"lon":120.0613669039592},{"lat":30.325013470741624,"lon":120.0613777168136},{"lat":30.325013196152614,"lon":120.06139173368659},{"lat":30.325008415846558,"lon":120.06140294678971},{"lat":30.325001030452782,"lon":120.06141155653043},{"lat":30.32499705260998,"lon":120.06142407125877},{"lat":30.324999088663304,"lon":120.06144379516473},{"lat":30.324998813675155,"lon":120.06145761175561},{"lat":30.324999341693346,"lon":120.06147303033119},{"lat":30.325000166841242,"lon":120.06148684699785},{"lat":30.32500189391938,"lon":120.06150166493458},{"lat":30.325000618943324,"lon":120.06151558152455},{"lat":30.32500063580178,"lon":120.06152489269367},{"lat":30.324996259660495,"lon":120.0615384085247},{"lat":30.324988782722013,"lon":120.06155172384325},{"lat":30.324985012082166,"lon":120.06156824330593},{"lat":30.324977328583167,"lon":120.0615779542757},{"lat":30.324969243758257,"lon":120.06158696436856},{"lat":30.324962857354993,"lon":120.06159497340515},{"lat":30.32495836578271,"lon":120.06159997900893},{"lat":30.324958586980177,"lon":120.06161169303262},{"lat":30.324956602985104,"lon":120.06162070363216},{"lat":30.324954121268842,"lon":120.06163101574029},{"lat":30.324950346962346,"lon":120.06164553275373},{"lat":30.32494816780785,"lon":120.06165724654882},{"lat":30.3249488919391,"lon":120.06167056249598},{"lat":30.3249450107322,"lon":120.06168127493919},{"lat":30.324939528035873,"lon":120.06169128640548},{"lat":30.32493154426852,"lon":120.06170089717688},{"lat":30.324924463871216,"lon":120.06171231016725},{"lat":30.32491747969254,"lon":120.0617216206573},{"lat":30.32491179568982,"lon":120.06173093125435},{"lat":30.32490103479143,"lon":120.06175345713139},{"lat":30.32489638084361,"lon":120.06177938755012},{"lat":30.324894192436478,"lon":120.0617859952113},{"lat":30.324895715169507,"lon":120.06179851019908},{"lat":30.324896943619173,"lon":120.06181422895547},{"lat":30.32489466851535,"lon":120.06182824538409},{"lat":30.324884185072136,"lon":120.06183825635792},{"lat":30.32487149736184,"lon":120.06184606452968},{"lat":30.324858712155017,"lon":120.06185527435055},{"lat":30.32485552736901,"lon":120.06186398439372},{"lat":30.32485454162411,"lon":120.06187199379151},{"lat":30.324853259612418,"lon":120.06188210564892},{"lat":30.3248490755785,"lon":120.06189131618848},{"lat":30.324842589965662,"lon":120.06189982569927},{"lat":30.324825901146262,"lon":120.06190733315314},{"lat":30.32481731487927,"lon":120.06191564224206},{"lat":30.324804832923604,"lon":120.06192665418877},{"lat":30.324788 ...
# rows.attribute: String, 1
# rows.adminId: Integer, 36
# rows.adminName: String, 陈宝元
# rows.crops: String, 1,2
# rows.status: String, 1
# rows.source: String, 1
# rows.sourceId: String, 1859527062484348931
# rows.attributeName: String, 自有
# rows.adminTel: String, 19975382373
# code: Integer, 200
# msg: String, 查询成功
#
#
# /remote/sense/type/list
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /remote/sense/level/list?typeId=10146&cropId=
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# typeId: String, 10146 检测项
# cropId: String,  作物（废弃）
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# code: Integer, 200
# rows: Array,
# rows.amount: Number, 1.23
# rows.bankCardCode: String, 银行卡号
# rows.bankName: String, 银行名称
# rows.corpId: Integer, 1
# rows.id: Integer, 6
# rows.isSys: Boolean, false
# rows.name: String, 名称
# rows.remark: String, 备注
# rows.shops: Array,
# rows.shops.id: Integer, 1
# total: Integer, 6
#
#
# /machinery/abnormalInfo/stats/getStats?params[beginTime]=2024-12-12&params[endTime]=&deptId=100
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# params[beginTime]: String, 2024-12-12 开始时间
# params[endTime]: String,  结束时间
# deptId: String, 100 部门id
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# msg: String, 操作成功
# code: Integer, 200
# data: Object,
# data.gradeStats: Array,  异常紧急程度统计数据列表
# data.gradeStats.abnormalType: Null, null
# data.gradeStats.abnormalTypeName: Null, null
# data.gradeStats.grade: String, 1 紧急程度 1-非常紧急 2-紧急 3-一般
# data.gradeStats.gradeName: String, 1级（非常紧急）
# data.gradeStats.totalNum: Integer, 0
# data.abnormalTypeStats: Array,  异常分类统计数据列表
# data.abnormalTypeStats.abnormalType: String, 1 异常分类id
# data.abnormalTypeStats.abnormalTypeName: String, 病虫害 异常分类名称
# data.abnormalTypeStats.grade: Null, null
# data.abnormalTypeStats.gradeName: Null, null
# data.abnormalTypeStats.totalNum: Integer, 0 数量
#
#
# /machinery/abnormalInfo/stats/list?pageNum=1&pageSize=10&params[beginTime]=2024-12-11&params[endTime]=&abnormalType=1&deptId=
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# pageNum: String, 1
# pageSize: String, 10
# params[beginTime]: String, 2024-12-11 开始日期
# params[endTime]: String,  结束日期
# abnormalType: String, 1 异常分类 可多选 使用,分隔
# deptId: String,  部门id
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# total: Integer, 48
# pageNum: Integer, 1
# rows: Array,
# rows.createBy: String, 唐华杰
# rows.createTime: String, 2024-12-12 10:07:18 创建时间
# rows.updateBy: Null, null
# rows.updateTime: Null, null
# rows.remark: Null, null 备注
# rows.id: String, 2e512eb0c2b04071804bcf371569232c id
# rows.deptId: String, 100 部门id
# rows.location: String, 振中路208号艾健科技园3幢正南方向162米
# rows.locationType: String, 2
# rows.farmlandId: Null, null
# rows.locationLng: String, 120.0609170
# rows.locationLat: String, 30.3225300
# rows.polygon: Null, null
# rows.grade: String, 2
# rows.gradeName: String, 紧急
# rows.description: String, 111
# rows.tel: String, 13221018517
# rows.handleUserId: Null, null
# rows.handleUserTel: Null, null
# rows.handleUserName: Null, null
# rows.handleTime: Null, null
# rows.handleDept: Null, null
# rows.handleDesc: Null, null
# rows.status: String, 1
# rows.statusName: Null, null
# rows.statusToInt: Null, null
# rows.soure: String, 田间管理员
# rows.abnormalInfoFileList: Null, null
# rows.abnormalInfo: String, 1张照片，0个视频
# rows.abnormalProgressVoList: Null, null
# rows.readBy: String, 1
# rows.readTime: String, 2024-12-12 11:28:45
# rows.readTel: String, 15888888888
# rows.isRead: String, 1
# rows.isWeb: Null, null
# rows.isWx: Null, null
# rows.userIds: Null, null
# rows.abnormalType: String, 99 异常分类
# rows.abnormalTypeName: String, 其他 异常分类名
# code: Integer, 200
# msg: String, 查询成功
#
#
# //121.43.41.184:9999/rest/umc.user.login
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# username: String, dipu 用户名
# password: String, dipu@123456 密码
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# Data: Object,
# Data.Token: String, eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJleHAiOjE2NjI1NDcxOTEsInVzZXJuYW1lIjoiZGlwdSJ9.gzJHVvCx_Sl2ULr1rC-WTyGx7lCkkIV2V74boW9tsnc
# Data.Exp: String, 2022-09-07 19:09:51
# Code: Number, 0
#
#
# //121.43.41.184:9999/farmland/external/remoteSensingData/list
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
#
#
# //121.43.41.184:9999/farmland/external/remoteSensingData/getItemColor
# 输入项：
# 给出对每一个输入项的特性，包括名称、标识、数据的类型和格式、数据值的有效范围、输入的方式。数量和频度、输入媒体、输入数据的来源和安全保密条件等等。
# 无 body 请求参数
# 输出项：
# 给出对每一个输出项的特性，包括名称、标识、数据的类型和格式，数据值的有效范围，输出的形式、数量和频度，输出媒体、对输出图形及符号的说明、安全保密条件等等。
# 无请求参数
