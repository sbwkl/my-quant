# %%
from ibapi.client import *
from ibapi.wrapper import *
import datetime
import time
import threading

# %%
port = 7496

class TestApp(EClient, EWrapper):
    def __init__(self):
        EClient.__init__(self, self)
        self.hist_bars = []

    def nextValidId(self, orderId: OrderId):
        self.orderId = orderId
    
    def nextId(self):
        self.orderId += 1
        return self.orderId
        
    def error(self, reqId: TickerId, errorTime: int, errorCode: int, errorString: str, advancedOrderRejectJson = ""):
        print("Error. Id:", reqId, errorTime, "Code:", errorCode, "Msg:", errorString, "AdvancedOrderRejectJson:", advancedOrderRejectJson)
            
    def connectClosed(self):
        print("API Connection Lost.")
        
    def headTimestamp(self, reqId, headTimeStamp):
        print(headTimeStamp)
        print(datetime.datetime.fromtimestamp(int(headTimeStamp)))
        self.cancelHeadTimeStamp(reqId)
        
    def historicalData(self, reqId, bar):
        self.hist_bars.append(bar)
    
    def historicalDataEnd(self, reqId, start, end):
        print(f"Historical Data Ended for {reqId}. Started at {start}, ending at {end}")
        self.cancelHistoricalData(reqId)

app = TestApp()
app.connect("127.0.0.1", port, 2)
threading.Thread(target=app.run).start()
time.sleep(5)

# %%
app.disconnect()

# %%
PL = Contract()
PL.symbol = "PL"
PL.secType = "CONTFUT"
PL.exchange = "NYMEX"
PL.currency = "USD"

M_PT = Contract()
M_PT.symbol = "M-PT"
M_PT.secType = "CONTFUT"
M_PT.exchange = "OSE.JPN"
M_PT.currency = "JPY"

PLAT = Contract()
PLAT.symbol = "PLAT"
PLAT.secType = "CONTFUT"
PLAT.exchange = "OSE.JPN"
PLAT.currency = "JPY"

USDJPY = Contract()
USDJPY.symbol = "USD"
USDJPY.secType = "CASH"
USDJPY.exchange = "IDEALPRO"
USDJPY.currency = "JPY"

USDCNH = Contract()
USDCNH.symbol = "USD"
USDCNH.secType = "CASH"
USDCNH.exchange = "IDEALPRO"
USDCNH.currency = "CNH"

# app.error = lambda reqId, errorTime, errorCode, errorString, advancedOrderRejectJson = "": print(errorString)

# app.reqHeadTimeStamp(app.nextId(), PLAT, "TRADES", 1, 2)
# app.reqHeadTimeStamp(app.nextId(), USDCNH, "MIDPOINT", 1, 2)
app.reqHistoricalData(app.nextId(), PL, "", "1 D", "1 hour", "TRADES", 1, 1, False, [])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 35
#      29 USDCNH.currency = "CNH"
#      31 # app.error = lambda reqId, errorTime, errorCode, errorString, advancedOrderRejectJson = "": print(errorString)
#      32
#      33 # app.reqHeadTimeStamp(app.nextId(), PLAT, "TRADES", 1, 2)
#      34 # app.reqHeadTimeStamp(app.nextId(), USDCNH, "MIDPOINT", 1, 2)
# ---> 35 app.reqHistoricalData(app.nextId(), PL, "", "1 D", "1 hour", "TRADES", 1, 1, False, [])
#
# Cell In[22], line 12, in TestApp.nextId(self)
#      11 def nextId(self):
# ---> 12     self.orderId += 1
#      13     return self.orderId
#
# AttributeError: 'TestApp' object has no attribute 'orderId'
# Error. Id: -1 0 Code: 2103 Msg: Market data farm connection is broken:hfarm AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2103 Msg: Market data farm connection is broken:usfuture AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2103 Msg: Market data farm connection is broken:jfarm AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2105 Msg: HMDS data farm connection is broken:ushmds AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2103 Msg: Market data farm connection is broken:cashfarm AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2157 Msg: Sec-def data farm connection is broken:secdefhk AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2105 Msg: HMDS data farm connection is broken:apachmds AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2103 Msg: Market data farm connection is broken:usfarm AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2105 Msg: HMDS data farm connection is broken:fundfarm AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2105 Msg: HMDS data farm connection is broken:euhmds AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2105 Msg: HMDS data farm connection is broken:cashhmds AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2106 Msg: HMDS data farm connection is OK:apachmds AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2158 Msg: Sec-def data farm connection is OK:secdefhk AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2104 Msg: Market data farm connection is OK:jfarm AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2104 Msg: Market data farm connection is OK:hfarm AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2106 Msg: HMDS data farm connection is OK:ushmds AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2106 Msg: HMDS data farm connection is OK:euhmds AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2106 Msg: HMDS data farm connection is OK:fundfarm AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2104 Msg: Market data farm connection is OK:usfuture AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2104 Msg: Market data farm connection is OK:usfarm AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2104 Msg: Market data farm connection is OK:cashfarm AdvancedOrderRejectJson:
# Error. Id: -1 0 Code: 2106 Msg: HMDS data farm connection is OK:cashhmds AdvancedOrderRejectJson:
